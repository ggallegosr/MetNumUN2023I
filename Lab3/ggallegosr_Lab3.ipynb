# %% [markdown]
# **LABORATORIO 3**
#
# Gabriela Gallegos Rubio
#
#
# Los certificados aparecen en el apartado de "Licencias y Certificaciones"
#
# [ Clik aquí para ver el Linkedin](https://linkedin.com/in/gabriela-gallegos-rubio-46a668186)
#
# ![Linkedin- certificaciones.png](data:image/png;base64,...)
#
# **Certificado Data Analysis with Python**
# ![Data Analysis with Python - ggallegosr.png](data:image/png;base64,...)
#
# **Certificado Data Visualization with Python**
# ![Data Visualization with Python - ggallegosr.png](data:image/png;base64,...)
#
# **Certificado Python 101 for Data Science**
# ![Python 101 for data science - ggallegosr.png](data:image/png;base64,...)
